# %% [markdown]
# # Visualization Time Series Data - Pandas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
# Python's date time library
from datetime import datetime

# %%
my_year = 2017
my_month = 1
my_day = 2
my_hour = 13
my_minute = 30
my_second = 15

# %%
my_date = datetime(my_year, my_month, my_day)

# %%
my_date
# Out:
# datetime.datetime(2017, 1, 2, 0, 0)

# %%
my_date_time = datetime(my_year, my_month, my_day, my_hour, my_minute, my_second)

# %%
my_date_time
# Out:
# datetime.datetime(2017, 1, 2, 13, 30, 15)

# %%
type(my_date_time)
# Out:
# datetime.datetime

# %%
my_date_time.day
# Out:
# 2

# %%
first_two = [datetime(2016, 1, 1), datetime(2016, 1, 2)]

# %%
first_two
# Out:
# [datetime.datetime(2016, 1, 1, 0, 0), datetime.datetime(2016, 1, 2, 0, 0)]

# %%
type(first_two)
# Out:
# list

# %% [markdown]
# ## Creating a Dataframe

# %%
# convert to index
dt_ind = pd.DatetimeIndex(first_two)

# %%
dt_ind
# Out:
# DatetimeIndex(['2016-01-01', '2016-01-02'], dtype='datetime64[ns]', freq=None)

# %%
data = np.random.randn(2, 2)
data
# Out:
# array([[-1.71235705, -2.61101665],
#        [-0.82141405,  0.49332126]])

# %%
cols = ['a', 'b']

# %%
df = pd.DataFrame(data, index=dt_ind, columns=cols)

# %%
df
# Out:
#                    a         b
# 2016-01-01 -1.712357 -2.611017
# 2016-01-02 -0.821414  0.493321

# %%
df.index.argmax()
# Out:
# np.int64(1)

# %%
# latest date in the index
df.index.max()
# Out:
# Timestamp('2016-01-02 00:00:00')

# %%
df.index.argmin()
# Out:
# np.int64(0)

# %%
# earliest date in the index
df.index.min()
# Out:
# Timestamp('2016-01-01 00:00:00')
