# %% [markdown]
# # Pandas Data Input and Output - Reading CSV and other Data

# %%
import pandas as pd

# %%
# %cd "/Users/tanojudawattage/1_tanoj/0.00_Cloud_Computing_and_Streaming_Tech/Python_for_Finance_Files/03- General Pandas"
# Out:
# /Users/tanojudawattage/1_tanoj/0.00_Cloud_Computing_and_Streaming_Tech/Python_for_Finance_Files/03- General Pandas

# %%
df = pd.read_csv("example")

# %% [markdown]
# **Install libraries** <br/>
# pip or conda install lxml<br>
# pip or conda install html5lib<br>
# pip or conda install BeautifulSoup4<br>

# %%
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df.to_csv("My_output", index=False)

# %%
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %% [markdown]
# # Excel worksheets

# %%
# working with excel file workbooks
pd.read_excel("Excel_Sample.xlsx", sheet_name="Sheet1")
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
# write dataframe to excel
df.to_excel("Excel_Sample2.xlsx", sheet_name="NewSheet")

# %% [markdown]
# # Reading form HTML

# %%
data = pd.read_html('http://www.fdic.gov/bank/individual/failed/banklist.html')

# %% [markdown]
# Pandas will convert the table markings in the HTML tags into a dataframe

# %%
data[0].head()
# Out:
#                                Bank Name          City         State   Cert  \
# 0           The Santa Anna National Bank    Santa Anna         Texas   5520
# 1                   Pulaski Savings Bank       Chicago      Illinois  28611
# 2     The First National Bank of Lindsay       Lindsay      Oklahoma   4134
# 3  Republic First Bank dba Republic Bank  Philadelphia  Pennsylvania  27332
# 4                          Citizens Bank      Sac City          Iowa   8758
#
#                Acquiring Institution      Closing Date  Fund  Sort ascending
# 0          Coleman County State Bank     June 27, 2025                 10549
# 1                    Millennium Bank  January 17, 2025                 10548
# 2             First Bank & Trust Co.  October 18, 2024                 10547
# 3  Fulton Bank, National Association    April 26, 2024                 10546
# 4          Iowa Trust & Savings Bank  November 3, 2023                 10545

# %% [markdown]
# # SQL Engine

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///:memory:')

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# write df to sql table engine
df.to_sql('my_table', engine)
# Out:
# 4

# %%
sqldf = pd.read_sql('my_table', con=engine)

# %%
sqldf
# Out:
#    index   a   b   c   d
# 0      0   0   1   2   3
# 1      1   4   5   6   7
# 2      2   8   9  10  11
# 3      3  12  13  14  15
